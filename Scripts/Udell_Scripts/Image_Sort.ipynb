# %%
import cv2
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\moin2\OneDrive - University of Georgia\Spring 2023\Silene\Imageant\silene.csv")
petal = dataset[dataset["petal_color"] == "White"]
file = petal["file"]

for i in file:
    
    # Define the path to the image and load it
    image = cv2.imread(r"C:\Users\moin2\OneDrive - University of Georgia\Spring 2023\Silene\AllPhotos" + "\\" + str(i))
    
    # Save image to new path
    cv2.imwrite(r"C:\Users\moin2\OneDrive - University of Georgia\Spring 2023\Silene\White" + "\\" + str(i), image)

# %%
dataset = pd.read_csv(r"E:\UGA\Fall 2022\Rotation 2\Imageant\dissectum_files.csv")
anther = dataset["Anther"]

for i in anther:
    
    # Define the path to the image and load it
    image = cv2.imread(r"E:\UGA\Fall 2022\Rotation 2\Imageant\dissectum" + "\\" + str(i))
    
    # Save image to new path
    cv2.imwrite(r"E:\UGA\Fall 2022\Rotation 2\Imageant\dissectum_Anthers" + "\\" + str(i), image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       7 image = cv2.imread(r"E:\UGA\Fall 2022\Rotation 2\Imageant\dissectum" + "\\" + str(i))
#       9 # Save image to new path
# ---> 10 cv2.imwrite(r"E:\UGA\Fall 2022\Rotation 2\Imageant\dissectum_Anthers" + "\\" + str(i), image)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
